# %%
from sklearn.metrics import silhouette_score
from sklearn.datasets.samples_generator import make_blobs
X, y = make_blobs(n_samples=500, centers=5, n_features=3)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
val = []
lamda = []

for x in range(2,10):
    clusterer = KMeans(n_clusters=x, random_state=10)
    cluster_labels = clusterer.fit_predict(X)
    score = silhouette_score(X,cluster_labels)
    print("for ",x,"clusters, silhouette score = ",score)
    fig=plt.figure(figsize=(20,10))
    ax=fig.add_subplot(111)
    p=ax.scatter(X[:,0],X[:,1],c=cluster_labels)
    fig.colorbar(p)
    plt.show()
    val.append(x)
    lamda.append(score)

plt.plot(val,lamda)
plt.show()
# Out:
# for  2 clusters, silhouette score =  0.436326950112
# for  3 clusters, silhouette score =  0.55098277399
# for  4 clusters, silhouette score =  0.695041847988
# for  5 clusters, silhouette score =  0.821892024634
# for  6 clusters, silhouette score =  0.749858398663
# for  7 clusters, silhouette score =  0.642875014712
# for  8 clusters, silhouette score =  0.572508016504
# for  9 clusters, silhouette score =  0.436217542065
