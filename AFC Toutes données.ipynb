# %% [markdown]
# Récupération

# %%
import os
os.chdir('/home/garance/Bureau')
import pandas as pd
data = pd.read_csv("decathlon.txt", sep="\t")
mydata = data.drop(['Points', 'Rank', 'Competition'], axis=1)
X = mydata.values
data
# Out:
#               100m  Long.jump  Shot.put  High.jump   400m  110m.hurdle  \
# SEBRLE       11.04       7.58     14.83       2.07  49.81        14.69
# CLAY         10.76       7.40     14.26       1.86  49.37        14.05
# KARPOV       11.02       7.30     14.77       2.04  48.37        14.09
# BERNARD      11.02       7.23     14.25       1.92  48.93        14.99
# YURKOV       11.34       7.09     15.19       2.10  50.42        15.31
# WARNERS      11.11       7.60     14.31       1.98  48.68        14.23
# ZSIVOCZKY    11.13       7.30     13.48       2.01  48.62        14.17
# McMULLEN     10.83       7.31     13.76       2.13  49.91        14.38
# MARTINEAU    11.64       6.81     14.57       1.95  50.14        14.93
# HERNU        11.37       7.56     14.41       1.86  51.10        15.06
# BARRAS       11.33       6.97     14.09       1.95  49.48        14.48
# NOOL         11.33       7.27     12.68       1.98  49.20        15.29
# ...

# %% [markdown]
# Standardisation

# %%
from sklearn import preprocessing
std_scale = preprocessing.StandardScaler().fit(X)
X_scaled = std_scale.transform(X)

# %% [markdown]
# AFC

# %%
from sklearn import decomposition

afc = decomposition.FactorAnalysis(n_components=2)
afc.fit(X_scaled)
print(afc.score(X_scaled))
# Out:
# -12.8698256671

# %%
X_projected = afc.transform(X_scaled)
print X_projected.shape
# Out:
# (41, 2)

# %% [markdown]
# Visualisation

# %%
import matplotlib.pyplot as plt
color = data.get("Rank")
color *= (-1)
fig = plt.figure(figsize=(20,10))
plt.scatter(X_projected[:,0],X_projected[:,1],c=color, s=1000)
for i, (x,y) in enumerate(zip(X_projected[:,0],
                             X_projected[:,1])):
    plt.text(x,y, data.index[i], fontsize=25)
plt.xlabel("PC 1")
plt.ylabel("PC 2")
plt.colorbar()
plt.show()

# %%
#Structure de composition
pcs = afc.components_
figure = plt.figure(figsize=(15,15))
for i, (x,y) in enumerate(zip(pcs[0,:],pcs[1,:])):
    plt.plot([0,x],[0,y])
    plt.text(x,y,data.columns[i],fontsize=25)
plt.xlabel("PC 1")
plt.ylabel("PC 2")

plt.show()

# %% [markdown]
# 3D ?

# %%
from sklearn import decomposition

afc = decomposition.FactorAnalysis(n_components=3)
afc.fit(X_scaled)
print(pca.score(X_scaled))
# Out:
# -12.6055905478

# %%
X_projected = afc.transform(X_scaled)
print X_projected.shape
# Out:
# (41, 3)

# %% [markdown]
# Visualisation

# %%
from mpl_toolkits.mplot3d import Axes3D
coulour = data.get("Rank")
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
size = X_projected[:,0]**0+1000
p=ax.scatter(X_projected[:,0],X_projected[:,1], X_projected[:,2], c=coulour, s=size)

for i, (x,y,z) in enumerate(zip(X_projected[:,0],
                             X_projected[:,1],
                               X_projected[:,2])):
    ax.text(x,y,z, data.index[i],color='k',fontsize=15)
    
ax.set_xlabel("PC 1")
ax.set_ylabel("PC 2")
ax.set_zlabel("PC 3")
ax.set_xlim([-2, 2])
ax.set_ylim([-1, 3])
ax.set_zlim([-3, 1])
fig.colorbar(p)

plt.show()

# %%
#Structure de composition
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')


pcs = pca.components_

for i, (x,y,z) in enumerate(zip(pcs[0,:],pcs[1,:], pcs[2,:])):
    ax.plot([0,x],[0,y],[0,z])
    ax.text(x,y,z,data.columns[i],fontsize=15)
    
ax.set_xlabel("PC 1")
ax.set_ylabel("PC 2")
ax.set_zlabel("PC 3")
ax.set_xlim([-0.2,.8])
ax.set_ylim([-0.4,.8])
ax.set_zlim([-.6,0.6])


plt.show()
